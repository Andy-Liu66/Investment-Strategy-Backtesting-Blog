# %% [markdown]
# # 輸入套件

# %%
# 自製模組套件
from preprocess import Data
from backtest import Backtest

# 外部套件
import os
from operators import lag

# %% [markdown]
# # 輸入資料，共有4種月營收資料：
# 1. 單月合併營收創N個月新高
#
# 2. 單月合併營收連N個月遞增
#
# 3. 單月合併營收年成長(%)連N個月大於零
#
# 4. 累計合併營收成長(%)連N個月大於零
#
# # 欲檢視不同因子則於底下更改使用資料(data_name)名稱即可，同樣也可以透過for loop代入不同參數同時儲存績效結果

# %%
# 檢視可使用資料
os.listdir('data')
# Out:
# ['benchmark.csv',
#  'close_price.csv',
#  'market_size.csv',
#  'open_price.csv',
#  'vol.csv',
#  '單月合併營收創N個月新高_已格式化.csv',
#  '單月合併營收年成長(%)連N個月大於零_已格式化.csv',
#  '單月合併營收連N個月遞增_已格式化.csv',
#  '單月營收年成長(%)_已格式化.csv',
#  '收盤價_未還原_已格式化.csv',
#  '累計合併營收成長(%)連N個月大於零_已格式化.csv']

# %%
data_name = '單月合併營收創N個月新高_已格式化'

# 建立Data物件
month_growth = Data(
    data_name=data_name,
    data_frequency='month',
    market_size_threshold=200
)

# %% [markdown]
# # 定義濾網

# %%
n = 6

# 此處用法為大於門檻值才回傳，若需拆解特定月份績效，則使用return series==n
def bigger_than_n(series):
    return series >= n

# %% [markdown]
# # 加入濾網、篩選條件、計算自定義數值分析

# %%
month_growth.add_filter(bigger_than_n)
# Out:
# 篩選條件 - 'bigger_than_n' 已新增!
# 市值條件 - '200億以上' 門檻已選擇！

# %% [markdown]
# # 開始回測

# %%
signal_list = [
    month_growth
]

backtesting = Backtest(
    signal_list,
    start_date='2010/1/1',
    end_date='2019/6/30'
)
backtesting.run()
# Out:
# Progress: 100% |#######################| Elapsed Time: 0:00:10 , Time: 0:00:10

# %% [markdown]
# # 分析結果

# %%
from analysis import Analysis

backtesting_result = Analysis(backtesting, tax_rate=0, fee_rate=0)
backtesting_result.run()
# Out:
# Progress: 100% |#######################| Elapsed Time: 0:01:22 , Time: 0:01:22

# %%
backtesting_result.plot_cumulative_return(weight_method='naive_weight')

# %%
backtesting_result.plot_profit_and_loss(weight_method='cap_weight', frequency='month')

# %%
backtesting_result.plot_return_heatmap(weight_method='cap_weight')

# %%
backtesting_result.summary()
# Out:
# =========================================  ===========  ==============  ============
# Backtesting result                         Benchmark    Naive weight    Cap weight
# =========================================  ===========  ==============  ============
# Start date                                 2010/01/01   2010/01/01      2010/01/01
# End date                                   2019/06/30   2019/06/30      2019/06/30
# Duration (years)                           9.5          9.5             9.5
# Total trade                                NA           4496            4496
# Total entry times                          NA           115             115
# Average trade number per entry             NA           39.1            39.1
# Average holding days                       NA           30              30
# Cumulative return                          83.67%       69.73%          23.42%
# Annual return                              7.58%        7.58%           4.35%
# CAGR                                       6.61%        5.73%           2.24%
# Historical high of equity                  88.03%       96.3%           58.93%
# Historical low of equity                   -13.83%      -16.2%          -12.71%
# Maximum drawdown                           -24.52%      -34.62%         -39.95%
# Total return over max drawdown             3.41         2.01            0.59
# Maximum outperformance                     NA           21.99%          34.51%
# Minimum underperformance                   NA           -20.71%         -62.52%
# Maximum under water days                   649          737             1566
# Winning rate (portfolio)                   54.15%       54.6%           53.1%
# Measured by each period-individual stock
# Winning rate (individual stock)            NA           50.23%          50.23%
# Win loss ratio                             NA           1.55            1.55
# Expected return                            NA           0.28            0.28
# Winning rate (compare to benchmark)        NA           45.38%          45.38%
# Win loss ratio (compare to benchmark)      NA           1.3             1.3
# Expected return (compare to benchmark)     NA           0.04            0.04
# Measured by whole period-individual stock
# Winning rate (individual stock)            NA           51.49%          51.49%
# Win loss ratio                             NA           1.12            1.12
# Expected return                            NA           0.09            0.09
# Winning rate (compare to benchmark)        NA           46.04%          46.04%
# Win loss ratio (compare to benchmark)      NA           1.15            1.15
# Expected return (compare to benchmark)     NA           -0.01           -0.01
# Standard deviation (annualized)            14.64%       19.57%          20.43%
# Sharpe ratio (annualized)                  51.74%       38.74%          21.27%
# Information ratio (annualized)             NA           0.01%           -16.0%
# Alpha                                      NA           0.02%           0.0%
# Alpha's p value                            NA           48.99%          94.79%
# Beta                                       NA           45.08%          51.97%
# Beta's p value                             NA           0.0%            0.0%
# Total turnover times                       NA           74.03           74.03
# Total transaction cost                     NA           0.0%            0.0%
# =========================================  ===========  ==============  ============
