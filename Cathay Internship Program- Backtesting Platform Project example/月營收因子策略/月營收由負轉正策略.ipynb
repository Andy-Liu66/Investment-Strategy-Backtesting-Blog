# %% [markdown]
# # 輸入套件

# %%
# 自製模組套件
from preprocess import Data
from backtest import Backtest

# 外部套件
import os
from operators import lag

# %% [markdown]
# # 輸入資料

# %%
# 檢視可使用資料
os.listdir('data')
# Out:
# ['benchmark.csv',
#  'close_price.csv',
#  'market_size.csv',
#  'open_price.csv',
#  'vol.csv',
#  '單月合併營收創N個月新高_已格式化.csv',
#  '單月合併營收年成長(%)連N個月大於零_已格式化.csv',
#  '單月合併營收連N個月遞增_已格式化.csv',
#  '單月營收年成長(%)_已格式化.csv',
#  '收盤價_未還原_已格式化.csv',
#  '累計合併營收成長(%)連N個月大於零_已格式化.csv']

# %%
# 建立Data物件
month_growth = Data(
    data_name='單月營收年成長(%)_已格式化',
    data_frequency='month',
    market_size_threshold=200
)

# %% [markdown]
# # 定義篩選條件、計算公式

# %%
from operators import lag

def growth_filter(series):
    '''
    營收YoY負轉正
    '''
    return (
        (lag(series , 1) < 0) &
        (series > 0)
    )

# %% [markdown]
# # 加入濾網、篩選條件、計算自定義數值分析

# %%
month_growth.add_filter(growth_filter)
# Out:
# 篩選條件 - 'growth_filter' 已新增!
# 市值條件 - '200億以上' 門檻已選擇！

# %% [markdown]
# # 開始回測

# %%
signal_list = [
    month_growth
]

backtesting = Backtest(
    signal_list,
    start_date='2010/1/1',
    end_date='2019/6/30'
)
backtesting.run()
# Out:
# Progress: 100% |#######################| Elapsed Time: 0:00:07 , Time: 0:00:07

# %% [markdown]
# # 分析結果

# %%
from analysis import Analysis

backtesting_result = Analysis(backtesting, tax_rate=0, fee_rate=0)
backtesting_result.run()
# Out:
# Progress: 100% |#######################| Elapsed Time: 0:00:35 , Time: 0:00:35

# %%
backtesting_result.plot_cumulative_return(weight_method='naive_weight')

# %%
backtesting_result.plot_profit_and_loss(weight_method='cap_weight', frequency='month')

# %%
backtesting_result.plot_return_heatmap(weight_method='cap_weight')

# %%
backtesting_result.summary()
# Out:
# =========================================  ===========  ==============  ============
# Backtesting result                         Benchmark    Naive weight    Cap weight
# =========================================  ===========  ==============  ============
# Start date                                 2010/01/01   2010/01/01      2010/01/01
# End date                                   2019/06/30   2019/06/30      2019/06/30
# Duration (years)                           9.5          9.5             9.5
# Total trade                                NA           2469            2469
# Total entry times                          NA           115             115
# Average trade number per entry             NA           21.47           21.47
# Average holding days                       NA           30              30
# Cumulative return                          83.67%       83.52%          97.15%
# Annual return                              7.58%        8.04%           8.81%
# CAGR                                       6.61%        6.6%            7.41%
# Historical high of equity                  88.03%       86.82%          98.67%
# Historical low of equity                   -13.83%      -15.8%          -13.49%
# Maximum drawdown                           -24.52%      -35.7%          -31.58%
# Total return over max drawdown             3.41         2.34            3.08
# Maximum outperformance                     NA           20.88%          20.13%
# Minimum underperformance                   NA           -22.86%         -21.0%
# Maximum under water days                   649          722             979
# Winning rate (portfolio)                   54.15%       54.13%          54.0%
# Measured by each period-individual stock
# Winning rate (individual stock)            NA           50.39%          50.39%
# Win loss ratio                             NA           1.9             1.9
# Expected return                            NA           0.46            0.46
# Winning rate (compare to benchmark)        NA           45.92%          45.92%
# Win loss ratio (compare to benchmark)      NA           1.48            1.48
# Expected return (compare to benchmark)     NA           0.14            0.14
# Measured by whole period-individual stock
# Winning rate (individual stock)            NA           51.52%          51.52%
# Win loss ratio                             NA           1.13            1.13
# Expected return                            NA           0.1             0.1
# Winning rate (compare to benchmark)        NA           45.89%          45.89%
# Win loss ratio (compare to benchmark)      NA           1.18            1.18
# Expected return (compare to benchmark)     NA           0.0             0.0
# Standard deviation (annualized)            14.64%       17.58%          17.56%
# Sharpe ratio (annualized)                  51.74%       45.76%          50.16%
# Information ratio (annualized)             NA           2.5%            6.73%
# Alpha                                      NA           0.02%           0.02%
# Alpha's p value                            NA           36.74%          30.76%
# Beta                                       NA           42.02%          44.29%
# Beta's p value                             NA           0.0%            0.0%
# Total turnover times                       NA           114.5           114.5
# Total transaction cost                     NA           0.0%            0.0%
# =========================================  ===========  ==============  ============
