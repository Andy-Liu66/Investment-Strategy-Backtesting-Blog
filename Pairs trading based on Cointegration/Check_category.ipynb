# %%
import pandas as pd

# %%
data = pd.read_table("category.csv", sep=",")
test = data[data["年月日"] == "20180615W5"]
test.groupby("TEJ產業_名稱").count().sort_values("證券代碼", ascending=False)
# Out:
#            證券代碼  簡稱  TEJ產業_代碼  年月日  收盤價(元)
# TEJ產業_名稱
# 電子零組件        90  90        90   90      90
# 光電/ IO       82  82        82   82      82
# 半導體          58  58        58   58      58
# 主機板          50  50        50   50      50
# 建設           43  43        43   43      43
# 金屬基本         33  33        33   33      33
# 汽車組件         28  28        28   28      28
# 資訊通路         26  26        26   26      26
# 機械業          23  23        23   23      23
# 成衣           23  23        23   23      23
# 藥            22  22        22   22      22
# 網路設備         22  22        22   22      22
# 石化           22  22        22   22      22
# 電子設備         19  19        19   19      19
# 通訊設備         18  18        18   18      18
# 消費性電子        16  16        16   16      16
# 金融控股         14  14        14   14      14
# PC系統         13  13        13   13      13
# 餐飲飯店         13  13        13   13      13
# 人纖           12  12        12   12      12
# ...
